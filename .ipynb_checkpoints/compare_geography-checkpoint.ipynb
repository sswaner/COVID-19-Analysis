# %%
import pandas as pd
import covid_daily

from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:100% !important; }</style>"))

df3 = covid_daily.covid_daily_report('04-13-2020')
df3.sort_values(by=['TPOP_MORTALITY'], ascending=False, inplace=True)
print(df3.columns)
display(df3.query("Deaths>0").head(20))
#display(df3.query("Admin2 in ['Rockland', 'Nassau', 'Blaine', 'Summit']").head(30))
# Out:
# <style>.container { width:100% !important; }</style>
# Index(['STATE', 'COUNTY', 'POPESTIMATE2019', 'DEATHS2019', 'FIPS', 'Admin2',
#        'Province_State', 'Confirmed', 'Deaths', 'TPOP_MORTALITY',
#        'CASE_MORTALITY', 'TPOP_CONFIRMED', 'Cases_per_1k', 'Deaths_per_1k'],
#       dtype='object')
#       STATE  COUNTY  POPESTIMATE2019  DEATHS2019   FIPS                Admin2  \
# 481      13     273             8531         115  13273               Terrell
# 1013     22      95            42837         421  22095  St. John the Baptist
# 467      13     243             6778          71  13243              Randolph
# 2670     36      61          8336817       62061  36061         New York City
# 397      13      95            87956         951  13095             Dougherty
# 1578     36      87           325789        2457  36087              Rockland
# 1830     40      55             5712          54  40055                 Greer
# ...
