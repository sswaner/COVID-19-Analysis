# %%
import pandas as pd


data = pd.read_csv("../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv")
df = pd.DataFrame(data)

display(df.query("FIPS>0").head(100))
# Out:
#          UID iso2 iso3  code3    FIPS               Admin2  \
# 0         16   AS  ASM     16    60.0                  NaN
# 1        316   GU  GUM    316    66.0                  NaN
# 2        580   MP  MNP    580    69.0                  NaN
# 3        630   PR  PRI    630    72.0                  NaN
# 4        850   VI  VIR    850    78.0                  NaN
# ..       ...  ...  ...    ...     ...                  ...
# 95  84002230   US  USA    840  2230.0              Skagway
# 96  84002240   US  USA    840  2240.0  Southeast Fairbanks
# 97  84002261   US  USA    840  2261.0       Valdez-Cordova
# 98  84002275   US  USA    840  2275.0             Wrangell
# 99  84002282   US  USA    840  2282.0              Yakutat
#
#               Province_State Country_Region        Lat       Long_  ...  \
# 0             American Samoa             US -14.271000 -170.132000  ...
# 1                       Guam             US  13.444300  144.793700  ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.close('all')

data = pd.read_csv("../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv")
df = pd.DataFrame(data)


ts_cols = df.columns[12:len(df.columns)]

#display(df.columns)
display(ts_cols)
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
#        '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20',
#        '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20',
#        '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20'],
# ...
