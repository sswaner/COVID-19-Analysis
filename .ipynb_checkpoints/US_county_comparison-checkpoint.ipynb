# %%
import pandas as pd
import covid_daily

from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:100% !important; }</style>"))

df3 = covid_daily.covid_daily_report('07-07-2020')
df3.sort_values(by=['Cases_per_1k'], ascending=False, inplace=True)
print(df3.columns)
display(df3.query("Deaths>0").head(20))
#display(df3.query("Admin2 in ['Rockland', 'Nassau', 'Blaine', 'Summit']").head(30))
# Out:
# <style>.container { width:100% !important; }</style>
# Index(['STATE', 'COUNTY', 'POPESTIMATE2019', 'DEATHS2019', 'FIPS', 'Admin2',
#        'Province_State', 'Confirmed', 'Deaths', 'TPOP_MORTALITY',
#        'CASE_MORTALITY', 'TPOP_CONFIRMED', 'Cases_per_1k', 'Deaths_per_1k'],
#       dtype='object')
#       STATE  COUNTY  POPESTIMATE2019  DEATHS2019   FIPS        Admin2  \
# 2458     47     169            11284          95  47169     Trousdale
# 140       5      77             8857         120   5077           Lee
# 1635     31      43            20026         129  31043        Dakota
# 783      19      21            19620         148  19021   Buena Vista
# 141       5      79            13024         146   5079       Lincoln
# 1343     27     105            21629         186  27105        Nobles
# 1109     22      35             6861          66  22035  East Carroll
# 1632     31      37            10709          72  31037        Colfax
# ...
